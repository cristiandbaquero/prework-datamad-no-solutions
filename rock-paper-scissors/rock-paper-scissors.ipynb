# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list


# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...



# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games


# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.



# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
    

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

    
# Print by console the winner of the game based on who has more accumulated wins

# %%
import random

options = ['stone', 'paper', 'scissors']
maximum_number_of_games = 10
victory = 3

machine_choice = random.choice(options)
machine_gets_one = 0
gamer_gets_one = 0
round_under_score = 0

while ((machine_gets_one < victory) | (gamer_gets_one < victory)) | (round_under_score == maximum_number_of_games):

    choice = str(input('Choose between stone, paper or scissors'))
    
    if (choice == ('stone')) | (choice == ('paper')) | (choice == ('scissors')):
        if (machine_choice == 'stone') & (choice == 'scissors'):
            machine_gets_one += 1
        elif (machine_choice == 'stone') & (choice == 'paper'):
            gamer_gets_one += 1
        elif (machine_choice == 'paper') & (choice == 'scissors'):
            gamer_gets_one += 1
        elif (machine_choice == 'paper') & (choice == 'stone'):
            machine_gets_one += 1
        elif (machine_choice == 'scissors') & (choice == 'stone'):
            gamer_gets_one += 1
        elif (machine_choice == 'scissors') & (choice == 'paper'):
            machine_gets_one += 1
        else:
            (machine_choice == choice)
            print(Tie)
        print('Machine choice:', machine_choice, 'Vs', 'Gamer choice:', choice)
        print('Machine score:', machine_gets_one, 'Gamer score:', gamer_gets_one)
        round_under_score =+ 1
    else: 
        print('Invalid option')

if machine_gets_one >= victory:
    print('Machine has won')
elif gamer_gets_one >= victory:
    print('Gamer has won')
# Out:
# Choose between stone, paper or scissorspaper
# Machine choice: stone Vs Gamer choice: paper
# Machine score: 0 Gamer score: 1
# Choose between stone, paper or scissorsscissors
# Machine choice: stone Vs Gamer choice: scissors
# Machine score: 1 Gamer score: 1
# Choose between stone, paper or scissorsstone
# Machine choice: stone Vs Gamer choice: stone
# Machine score: 1 Gamer score: 1
# Choose between stone, paper or scissorspaper
# Machine choice: stone Vs Gamer choice: paper
# Machine score: 1 Gamer score: 2
# Choose between stone, paper or scissorsstone
# Machine choice: stone Vs Gamer choice: stone
# Machine score: 1 Gamer score: 2
# Choose between stone, paper or scissorsscissors
# Machine choice: stone Vs Gamer choice: scissors
# Machine score: 2 Gamer score: 2
# Choose between stone, paper or scissorsscissors
# Machine choice: stone Vs Gamer choice: scissors
# Machine score: 3 Gamer score: 2
# Choose between stone, paper or scissorsstone
# Machine choice: stone Vs Gamer choice: stone
# Machine score: 3 Gamer score: 2
# Choose between stone, paper or scissorspaper
# Machine choice: stone Vs Gamer choice: paper
# Machine score: 3 Gamer score: 3
# machine has won

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module


# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking


# Assign a list of 5 possible options.


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.


# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options


    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
    
    
# Print by console the winner of the game based on who has more accumulated wins

# %%
import random

options = ['stone', 'paper', 'scissors', 'lizard', 'spock']

maximum_number_of_games = 20
victory = 4

machine_choice = random.choice(options)
machine_gets_one = 0
gamer_gets_one = 0
round_under_score = 0

odd_number = int(input('Choose an odd number on the keyboard from the range 1 to 9'))
    
if (odd_number == (1)) | (odd_number == (3)) | (odd_number == (5)) | (odd_number == (7)) | (odd_number == (9)):
        
    while ((machine_gets_one < victory) | (gamer_gets_one < victory)) | (round_under_score == maximum_number_of_games):
            
        choice = str(input('Choose between stone, paper, scissors, lizard or spock'))
            
        if (choice == ('stone')) | (choice == ('paper')) | (choice == ('scissors')) | (choice == ('lizard')) | (choice == ('spock')):
            if (machine_choice == 'stone') & (choice == 'scissors'):
                machine_gets_one += 1
            elif (machine_choice == 'stone') & (choice == 'paper'):
                gamer_gets_one += 1
            elif (machine_choice == 'stone') & (choice == 'lizard'):
                machine_gets_one += 1
            elif (machine_choice == 'stone') & (choice == 'spock'):
                gamer_gets_one += 1
            elif (machine_choice == 'paper') & (choice == 'scissors'):
                gamer_gets_one += 1
            elif (machine_choice == 'paper') & (choice == 'stone'):
                machine_gets_one += 1
            elif (machine_choice == 'paper') & (choice == 'lizard'):
                gamer_gets_one += 1
            elif (machine_choice == 'paper') & (choice == 'spock'):
                machine_gets_one += 1
            elif (machine_choice == 'scissors') & (choice == 'stone'):
                gamer_gets_one += 1
            elif (machine_choice == 'scissors') & (choice == 'paper'):
                machine_gets_one += 1
            elif (machine_choice == 'scissors') & (choice == 'lizard'):
                machine_gets_one += 1
            elif (machine_choice == 'scissors') & (choice == 'spock'):  
                gamer_gets_one += 1  
            elif (machine_choice == 'lizard') & (choice == 'stone'):
                gamer_gets_one += 1
            elif (machine_choice == 'lizard') & (choice == 'paper'):
                machine_gets_one += 1
            elif (machine_choice == 'lizard') & (choice == 'scissors'):
                gamer_gets_one += 1
            elif (machine_choice == 'lizard') & (choice == 'spock'):
                machine_gets_one += 1
            else:
                (machine_choice == choice)
                print(Tie)
            print('Machine choice:', machine_choice, 'Vs', 'Gamer choice:', choice)
            print('Machine score:', machine_gets_one, 'Gamer score:', gamer_gets_one)
            round_under_score =+ 1
        else: 
            print('Invalid option')
            
    else: 
        print('Invalid option')

if machine_gets_one >= victory:
    print('Machine has won')
elif gamer_gets_one >= victory:
    print('Gamer has won')
# Out:
# Choose an odd number on the keyboard from the range 1 to 99
# Choose between stone, paper, scissors, lizard or spockspock
# Machine choice: stone Vs Gamer choice: spock
# Machine score: 0 Gamer score: 1
# Choose between stone, paper, scissors, lizard or spocklizard
# Machine choice: stone Vs Gamer choice: lizard
# Machine score: 1 Gamer score: 1

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
